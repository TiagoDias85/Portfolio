# %%
import pandas as pd

# %%
filmes = pd.read_csv("Top_1000_IMDb_movies_New_version.csv")

# %%
filmes.head()
# Out:
#    Unnamed: 0                Movie Name Year of Release  Watch Time  \
# 0           0  The Shawshank Redemption            1994         142
# 1           1             The Godfather            1972         175
# 2           2           The Dark Knight            2008         152
# 3           3          Schindler's List            1993         195
# 4           4              12 Angry Men            1957          96
#
#    Movie Rating  Metascore of movie   Gross      Votes  \
# 0           9.3                82.0   28.34  27,77,378
# 1           9.2               100.0  134.97  19,33,588
# 2           9.0                84.0  534.86  27,54,087
# 3           9.0                95.0    96.9  13,97,886
# 4           9.0                97.0    4.36   8,24,211
#
#                                          Description
# 0  Over the course of several years, two convicts...
# 1  Don Vito Corleone, head of a mafia family, dec...
# 2  When the menace known as the Joker wreaks havo...
# ...

# %%
filmes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          1000 non-null   int64
#  1   Movie Name          1000 non-null   object
#  2   Year of Release     1000 non-null   object
#  3   Watch Time          1000 non-null   int64
#  4   Movie Rating        1000 non-null   float64
#  5   Metascore of movie  845 non-null    float64
#  6   Gross               838 non-null    object
#  7   Votes               1000 non-null   object
#  8   Description         1000 non-null   object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 70.4+ KB

# %%
filmes.columns = ["ID", "Nome do filme", "Ano de Estreia", "Tempo de Visualizacao", "Notas", "Metascore", "Lucro", "Votos", "Descricao"]

# %%
filmes[filmes['Notas'] > 8.0]
# Out:
#       ID             Nome do filme Ano de Estreia  Tempo de Visualizacao  \
# 0      0  The Shawshank Redemption           1994                    142
# 1      1             The Godfather           1972                    175
# 2      2           The Dark Knight           2008                    152
# 3      3          Schindler's List           1993                    195
# 4      4              12 Angry Men           1957                     96
# ..   ...                       ...            ...                    ...
# 339  339                    Eskiya           1996                    128
# 340  340            Chak De! India           2007                    153
# 341  341                     Black           2005                    122
# 342  342  Her Sey Çok Güzel Olacak           1998                    107
# 343  343                     Anand           1971                    122
#
#      Notas  Metascore   Lucro      Votos  \
# 0      9.3       82.0   28.34  27,77,378
# ...

# %%
#(indice, nome do filme, ano de produção, tempo )

# %%
filmes[(filmes['Notas'] > 8.0) & (filmes['Metascore'] > 90.0)]
# Out:
#       ID                                  Nome do filme Ano de Estreia  \
# 1      1                                  The Godfather           1972
# 3      3                               Schindler's List           1993
# 4      4                                   12 Angry Men           1957
# 5      5  The Lord of the Rings: The Return of the King           2003
# 8      8                                   Pulp Fiction           1994
# ..   ...                                            ...            ...
# 291  291                          Trois couleurs: Rouge           1994
# 293  293                                          Yi yi           2000
# 299  299                         La battaglia di Algeri           1966
# 314  314                      Du rififi chez les hommes           1955
# 325  325                  Sunrise: A Song of Two Humans           1927
#
#      Tempo de Visualizacao  Notas  Metascore   Lucro      Votos  \
# ...

# %%
WWII_movies = filmes[filmes['Descricao'].str.contains('World War II')]

# %%
print(WWII_movies)
# Out:
#       ID                Nome do filme Ano de Estreia  Tempo de Visualizacao  \
# 3      3             Schindler's List           1993                    195
# 46    46                  The Pianist           2002                    150
# 50    50               Hotaru no haka           1988                     89
# 73    73                 Idi i smotri           1985                    142
# 81    81                     Das Boot           1981                    149
# 93    93         Inglourious Basterds           2009                    153
# 170  170             The Great Escape           1963                    172
# 218  218                Hacksaw Ridge           2016                    139
# 284  284  The Best Years of Our Lives           1946                    170
# 349  349           The Imitation Game           2014                    114
# 440  440        Au revoir les enfants           1987                    104
# ...
