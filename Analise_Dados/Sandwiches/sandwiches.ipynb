# %%
import pandas as pd

# %%
df = pd.read_csv("Sub_Sandwiches_OSAT.csv")

# %%
display(df)
display(df.columns)
# Out:
#       Respondent_Serial           brand  OSAT  Food looks appetizing  \
# 0                     2          Subway     4                    6.0
# 1                     2       McDonalds     2                    5.0
# 2                     4          Subway     5                    4.0
# 3                     4       McDonalds     6                    3.0
# 4                     5  Firehouse Subs     5                    5.0
# ...                 ...             ...   ...                    ...
# 4197              24241    Jersey Mikes     7                    7.0
# 4198              24287          Subway     1                    NaN
# 4199              24287          Panera     3                    NaN
# 4200              24290    Jersey Mikes     4                    2.0
# 4201              24290     Jimmy Johns     3                    4.0
#
#       Has food that tastes good  Has food I crave  \
# 0                           5.0               3.0
# ...

# %%
df.dtypes
# Out:
# Respondent_Serial                                                   int64
# brand                                                              object
# OSAT                                                                int64
# Food looks appetizing                                             float64
# Has food that tastes good                                         float64
# Has food I crave                                                  float64
# Provides the right proportions of ingredients                     float64
# Has a wide variety of menu options                                float64
# Offers healthy/better-for-you menu options                        float64
# Is making changes to improve their food                           float64
# Has a unique, distinctive approach that makes food better         float64
# Has a wide range of ingredients                                   float64
# Portions are the right size for my appetite                       float64
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4202 entries, 0 to 4201
# Data columns (total 43 columns):
#  #   Column                                                          Non-Null Count  Dtype
# ---  ------                                                          --------------  -----
#  0   Respondent_Serial                                               4202 non-null   int64
#  1   brand                                                           4202 non-null   object
#  2   OSAT                                                            4202 non-null   int64
#  3   Food looks appetizing                                           4128 non-null   float64
#  4   Has food that tastes good                                       4138 non-null   float64
#  5   Has food I crave                                                4118 non-null   float64
#  6   Provides the right proportions of ingredients                   4123 non-null   float64
# ...

# %%
tratados = df.dropna()

tratados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2788 entries, 0 to 4201
# Data columns (total 43 columns):
#  #   Column                                                          Non-Null Count  Dtype
# ---  ------                                                          --------------  -----
#  0   Respondent_Serial                                               2788 non-null   int64
#  1   brand                                                           2788 non-null   object
#  2   OSAT                                                            2788 non-null   int64
#  3   Food looks appetizing                                           2788 non-null   float64
#  4   Has food that tastes good                                       2788 non-null   float64
#  5   Has food I crave                                                2788 non-null   float64
#  6   Provides the right proportions of ingredients                   2788 non-null   float64
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4202 entries, 0 to 4201
# Data columns (total 43 columns):
#  #   Column                                                          Non-Null Count  Dtype
# ---  ------                                                          --------------  -----
#  0   Respondent_Serial                                               4202 non-null   int64
#  1   brand                                                           4202 non-null   object
#  2   OSAT                                                            4202 non-null   int64
#  3   Food looks appetizing                                           4128 non-null   float64
#  4   Has food that tastes good                                       4138 non-null   float64
#  5   Has food I crave                                                4118 non-null   float64
#  6   Provides the right proportions of ingredients                   4123 non-null   float64
# ...
